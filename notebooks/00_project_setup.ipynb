# %%
from pathlib import Path

# If you run this notebook from notebooks/, root is the parent.
# If you run from project root, root is current directory.
cwd = Path.cwd()
PROJECT_ROOT = Path("c:/Users/dipes/OneDrive/Documents/Machine Learning/Python/Sign_Language/Sign_Language_Detection_new")
PROJECT_ROOT
# Out:
# WindowsPath('c:/Users/dipes/OneDrive/Documents/Machine Learning/Python/Sign_Language/Sign_Language_Detection_new')

# %%
folders = [
    "notebooks",
    "data/raw",
    "data/external",
    "data/processed",
    "data/asl_yolo/train/images",
    "data/asl_yolo/train/labels",
    "data/asl_yolo/val/images",
    "data/asl_yolo/val/labels",
    "data/asl_yolo/test/images",
    "data/asl_yolo/test/labels",
    "models/base",
    "models/trained",
    "runs",
    "outputs/predictions",
    "outputs/logs",
    "outputs/exported_models",
    "src",
]

for f in folders:
    (PROJECT_ROOT / f).mkdir(parents=True, exist_ok=True)

print("✅ Folder structure created/verified.")
# Out:
# ✅ Folder structure created/verified.

# %%
gitignore = """# Python
__pycache__/
*.pyc
.venv/
.env

# Jupyter
.ipynb_checkpoints/

# Ultralytics outputs
runs/

# Optional: don't commit big datasets by default
data/raw/
data/processed/
data/external/
"""

gi_path = PROJECT_ROOT / ".gitignore"
gi_path.write_text(gitignore, encoding="utf-8")
print(f"✅ Wrote {gi_path}")
print(gi_path.read_text())
# Out:
# ✅ Wrote c:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\Sign_Language_Detection_new\.gitignore
# # Python
# __pycache__/
# *.pyc
# .venv/
# .env
#
# # Jupyter
# .ipynb_checkpoints/
#
# # Ultralytics outputs
# runs/
#
# # Optional: don't commit big datasets by default
# data/raw/
# data/processed/
# data/external/

# %%
requirements = """ultralytics>=8.0.0
opencv-python
numpy
"""

req_path = PROJECT_ROOT / "requirements.txt"
req_path.write_text(requirements, encoding="utf-8")
print(f"✅ Wrote {req_path}")
print(req_path.read_text())
# Out:
# ✅ Wrote c:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\Sign_Language_Detection_new\requirements.txt
# ultralytics>=8.0.0
# opencv-python
# numpy

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # downloads if not present
print("✅ YOLO loaded successfully")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\dipes\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# ✅ YOLO loaded successfully

# %%
import sys
from pathlib import Path

cwd = Path.cwd()
PROJECT_ROOT = cwd.parent if cwd.name == "notebooks" else cwd

# Add project root to Python import path (only if not already there)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("PROJECT_ROOT:", PROJECT_ROOT)
print("Added to sys.path ✅")
# Out:
# PROJECT_ROOT: c:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new
# Added to sys.path ✅

# %%
(PROJECT_ROOT / "src" / "__init__.py").touch(exist_ok=True)
print("✅ src is now a package")
# Out:
# ✅ src is now a package

# %%
from pathlib import Path

PROJECT_ROOT = Path(r"c:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new")

print("Does src exist?", (PROJECT_ROOT / "src").exists())
print("Contents of project root:")
print(list(PROJECT_ROOT.iterdir()))
# Out:
# Does src exist? True
# Contents of project root:
# ...

# %%
print("Does config.py exist?", (PROJECT_ROOT / "src" / "config.py").exists())
# Out:
# Does config.py exist? False

# %%
config_py = """from pathlib import Path

PROJECT_ROOT = Path(__file__).resolve().parents[1]

DATA_DIR = PROJECT_ROOT / "data"
DATASET_DIR = DATA_DIR / "asl_yolo"
DATA_YAML = DATASET_DIR / "data.yaml"

MODELS_DIR = PROJECT_ROOT / "models"
BASE_MODELS_DIR = MODELS_DIR / "base"
TRAINED_MODELS_DIR = MODELS_DIR / "trained"
BEST_MODEL = TRAINED_MODELS_DIR / "best.pt"

RUNS_DIR = PROJECT_ROOT / "runs"
OUTPUTS_DIR = PROJECT_ROOT / "outputs"
PRED_DIR = OUTPUTS_DIR / "predictions"
"""

src_dir = PROJECT_ROOT / "src"
src_dir.mkdir(exist_ok=True)

(config_path := src_dir / "config.py").write_text(config_py)
(src_dir / "__init__.py").touch(exist_ok=True)

print("Recreated config.py at:", config_path)
# Out:
# Recreated config.py at: c:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\src\config.py

# %%
from src.config import DATASET_DIR, DATA_YAML, BEST_MODEL, RUNS_DIR, PRED_DIR

print("DATASET_DIR:", DATASET_DIR)
print("DATA_YAML:", DATA_YAML, "| exists:", DATA_YAML.exists())
print("BEST_MODEL:", BEST_MODEL, "| exists:", BEST_MODEL.exists())
print("RUNS_DIR:", RUNS_DIR, "| exists:", RUNS_DIR.exists())
print("PRED_DIR:", PRED_DIR, "| exists:", PRED_DIR.exists())
# Out:
# DATASET_DIR: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\data\asl_yolo
# DATA_YAML: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\data\asl_yolo\data.yaml | exists: False
# BEST_MODEL: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\models\trained\best.pt | exists: False
# RUNS_DIR: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\runs | exists: True
# PRED_DIR: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\outputs\predictions | exists: True
