# %%
import sys
from pathlib import Path

# %%
#setting up paths

cwd = Path.cwd()
PROJECT_ROOT = cwd.parent if cwd.name == "notebooks" else cwd
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import DATA_YAML, RUNS_DIR, TRAINED_MODELS_DIR, BEST_MODEL

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_YAML:", DATA_YAML, "| exists:", DATA_YAML.exists())
print("RUNS_DIR:", RUNS_DIR)
print("BEST_MODEL target:", BEST_MODEL)
# Out:
# PROJECT_ROOT: c:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new
# DATA_YAML: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\data\asl_yolo\data.yaml | exists: True
# RUNS_DIR: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\runs
# BEST_MODEL target: C:\Users\dipes\OneDrive\Documents\Machine Learning\Python\Sign_Language\sign_language_detection_new\models\trained\best.pt

# %%
from ultralytics import YOLO

BASE = "yolov8n.pt"   # fastest, good for debugging
model = YOLO(BASE)

print("✅ Loaded base model:", BASE)
# Out:
# ...
# ✅ Loaded base model: yolov8n.pt

# %%
#train(safe defaults aile ko laagi) will be replaced furtheryly
results = model.train(
    data=str(DATA_YAML),
    imgsz=320,
    epochs=10,       # start with 30; increase later
    batch=8,         # lower if you get out-of-memory
    device="cpu",        # 0 for GPU; use "cpu" if you don't have CUDA
    project=str(RUNS_DIR),
    name="asl_yolo_train",
    workers=2
)
# Out:
# Ultralytics 8.4.14  Python-3.11.11 torch-2.10.0+cpu CPU (12th Gen Intel Core i7-1250U)
# ...
